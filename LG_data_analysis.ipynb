# %%
import pandas as pd

#uploaded dataset
file_path = 'LG_Customer_Data.csv'
lg_data = pd.read_csv(file_path)

# Display the first few rows to understand the structure of the dataset
lg_data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# General dataset information
info_summary = lg_data.info()

# Checking for missing values
missing_values = lg_data.isnull().sum()

# Descriptive statistics for numerical columns
descriptive_stats = lg_data.describe()

info_summary, missing_values, descriptive_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# (None,
#  CustomerID                0
#  Gender                    0
#  Age                       0
#  Annual Income (k$)        0
#  Spending Score (1-100)    0
#  dtype: int64,
#         CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
#  count  200.000000  200.000000          200.000000              200.000000
#  mean   100.500000   38.850000           60.560000               50.200000
# ...

# %%
# Visualization of distributions and relationships

# Set a general style for plots
sns.set(style="whitegrid")

# Gender distribution
plt.figure(figsize=(6, 4))
sns.countplot(data=lg_customer_data, x="Gender", palette="pastel")
plt.title("Gender Distribution")
plt.ylabel("Count")
plt.show()

# Age distribution
plt.figure(figsize=(6, 4))
sns.histplot(lg_customer_data["Age"], bins=20, kde=True, color="skyblue")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.show()

# Annual Income distribution
plt.figure(figsize=(6, 4))
sns.histplot(lg_customer_data["Annual Income (k$)"], bins=20, kde=True, color="green")
plt.title("Annual Income Distribution")
plt.xlabel("Annual Income (k$)")
plt.show()

# Spending Score distribution
plt.figure(figsize=(6, 4))
sns.histplot(lg_customer_data["Spending Score (1-100)"], bins=20, kde=True, color="orange")
plt.title("Spending Score Distribution")
plt.xlabel("Spending Score")
plt.show()
